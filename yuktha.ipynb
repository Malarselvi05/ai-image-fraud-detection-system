MB 4.6 MB/s eta 0:00:09
#    --------------------------- ------------ 77.1/113.8 MB 4.6 MB/s eta 0:00:09
#    --------------------------- ------------ 78.4/113.8 MB 4.6 MB/s eta 0:00:08
#    --------------------------- ------------ 79.4/113.8 MB 4.6 MB/s eta 0:00:08
#    ---------------------------- ----------- 80.7/113.8 MB 4.6 MB/s eta 0:00:08
#    ---------------------------- ----------- 81.8/113.8 MB 4.6 MB/s eta 0:00:07
#    ----------------------------- ---------- 83.1/113.8 MB 4.6 MB/s eta 0:00:07
#    ----------------------------- ---------- 84.4/113.8 MB 4.7 MB/s eta 0:00:07
#    ------------------------------ --------- 85.5/113.8 MB 4.7 MB/s eta 0:00:07
#    ------------------------------ --------- 86.5/113.8 MB 4.7 MB/s eta 0:00:06
#    ------------------------------ --------- 88.1/113.8 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 88.9/113.8 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 89.9/113.8 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 90.4/113.8 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 91.0/113.8 MB 4.6 MB/s eta 0:00:05
#    -------------------------------- ------- 92.0/113.8 MB 4.6 MB/s eta 0:00:05
#    -------------------------------- ------- 93.3/113.8 MB 4.7 MB/s eta 0:00:05
#    --------------------------------- ------ 94.1/113.8 MB 4.7 MB/s eta 0:00:05
#    --------------------------------- ------ 94.6/113.8 MB 4.6 MB/s eta 0:00:05
#    --------------------------------- ------ 95.2/113.8 MB 4.6 MB/s eta 0:00:05
#    --------------------------------- ------ 95.9/113.8 MB 4.6 MB/s eta 0:00:04
#    --------------------------------- ------ 96.5/113.8 MB 4.6 MB/s eta 0:00:04
#    ---------------------------------- ----- 97.0/113.8 MB 4.6 MB/s eta 0:00:04
#    ---------------------------------- ----- 97.3/113.8 MB 4.6 MB/s eta 0:00:04
#    ---------------------------------- ----- 98.8/113.8 MB 4.6 MB/s eta 0:00:04
#    ---------------------------------- ----- 99.4/113.8 MB 4.5 MB/s eta 0:00:04
#    ----------------------------------- ---- 100.1/113.8 MB 4.5 MB/s eta 0:00:04
#    ----------------------------------- ---- 101.2/113.8 MB 4.5 MB/s eta 0:00:03
#    ----------------------------------- ---- 102.2/113.8 MB 4.5 MB/s eta 0:00:03
#    ------------------------------------ --- 103.3/113.8 MB 4.5 MB/s eta 0:00:03
#    ------------------------------------ --- 104.1/113.8 MB 4.5 MB/s eta 0:00:03
#    ------------------------------------- -- 105.4/113.8 MB 4.5 MB/s eta 0:00:02
#    ------------------------------------- -- 106.7/113.8 MB 4.6 MB/s eta 0:00:02
#    ------------------------------------- -- 108.0/113.8 MB 4.6 MB/s eta 0:00:02
#    -------------------------------------- - 108.8/113.8 MB 4.6 MB/s eta 0:00:02
#    -------------------------------------- - 109.6/113.8 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 110.4/113.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  111.1/113.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  111.9/113.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  113.0/113.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 113.8/113.8 MB 4.5 MB/s  0:00:25
# Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 5.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 5.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 4.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 4.4 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 4.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.7 MB/s  0:00:02
# Downloading pillow-12.1.1-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 4.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/7.0 MB 4.9 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.0 MB 4.7 MB/s eta 0:00:01
#    -------------------- ------------------- 3.7/7.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.0/7.0 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 4.9 MB/s  0:00:01
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 6.0 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.6 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, Pillow, kiwisolver, fonttools, cycler, contourpy, torch, matplotlib, torchvision
#
#    ---------------------------------------- 0/9 [pyparsing]
#    ---- ----------------------------------- 1/9 [Pillow]
#    ---- ----------------------------------- 1/9 [Pillow]
#    ---- ----------------------------------- 1/9 [Pillow]
#    ---- ----------------------------------- 1/9 [Pillow]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ------------- -------------------------- 3/9 [fonttools]
#    ---------------------- ----------------- 5/9 [contourpy]
#   Attempting uninstall: torch
#    ---------------------- ----------------- 5/9 [contourpy]
#     Found existing installation: torch 2.9.1
#    ---------------------- ----------------- 5/9 [contourpy]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#     Uninstalling torch-2.9.1:
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#       Successfully uninstalled torch-2.9.1
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    -------------------------- ------------- 6/9 [torch]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ---------------------------------------- 9/9 [torchvision]
#
# Successfully installed Pillow-12.1.1 contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.3.2 torch-2.10.0 torchvision-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataset_path = r"D:\Users\Lenova\Desktop\YukTha\dataset"

train_dir = os.path.join(dataset_path, "train")
val_dir = os.path.join(dataset_path, "val")

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
from torchvision import datasets

# %%
train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
val_dataset = datasets.ImageFolder(root=val_dir, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

print("Classes:", train_dataset.class_to_idx)
print("Train size:", len(train_dataset))
print("Validation size:", len(val_dataset))
# Out:
# Classes: {'ai': 0, 'real': 1}
# Train size: 3000
# Validation size: 600

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
model = models.mobilenet_v2(pretrained=True)

# Freeze feature layers
for param in model.features.parameters():
    param.requires_grad = False

# Replace classifier
model.classifier[1] = nn.Linear(model.last_channel, 2)

model = model.to(device)
# Out:
# c:\Users\Lenova\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Lenova\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=1e-4)

# %%
num_epochs = 6

for epoch in range(num_epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_acc = 100 * correct / total
    
    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Loss: {running_loss:.4f} "
          f"Train Accuracy: {train_acc:.2f}%")
# Out:
# Epoch [1/6] Loss: 108.6192 Train Accuracy: 71.40%
# Epoch [2/6] Loss: 79.7148 Train Accuracy: 86.37%
# Epoch [3/6] Loss: 65.2264 Train Accuracy: 89.13%
# Epoch [4/6] Loss: 58.4274 Train Accuracy: 90.63%
# Epoch [5/6] Loss: 53.4186 Train Accuracy: 91.13%
# Epoch [6/6] Loss: 49.7494 Train Accuracy: 90.83%

# %%
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in val_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
    

val_accuracy = np.mean(np.array(all_preds) == np.array(all_labels))
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

print("\nClassification Report:")
print(classification_report(all_labels, all_preds))

print("\nConfusion Matrix:")
print(confusion_matrix(all_labels, all_preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.eval()
#       2 all_preds = []
#       3 all_labels = []
#
# NameError: name 'model' is not defined

# %%
torch.save(model.state_dict(), "models/mobilenet_food_model.pth")

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %% [markdown]
# INFERENCE TIME CALCULATION

# %%
import time

model.eval()

sample_image, _ = next(iter(val_loader))
sample_image = sample_image[0].unsqueeze(0).to(device)

start = time.time()
with torch.no_grad():
    output = model(sample_image)
end = time.time()

print("Inference time (seconds):", end - start)
# Out:
# Inference time (seconds): 0.044744253158569336

# %% [markdown]
# Model load

# %%
import torch
import torch.nn as nn
from torchvision import models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = models.mobilenet_v2(pretrained=False)
model.classifier[1] = nn.Linear(model.last_channel, 2)

model.load_state_dict(torch.load(
    r"D:\Users\Lenova\Desktop\YukTha\models\mobilenet_food_model.pth",
    map_location=device
))

model = model.to(device)
model.eval()

print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# c:\Users\Lenova\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
import time
import numpy as np

model.eval()

times = []
correct = 0
total = 0

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        
        start = time.time()
        outputs = model(images)
        end = time.time()
        
        times.append(end - start)
        
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    misclassified = []




avg_time = np.mean(times)
accuracy = correct / total

print("Average Batch Inference Time:", avg_time)
print("Per Image Inference Time:", avg_time / images.size(0))
print("Accuracy Check:", accuracy)
# Out:
# Average Batch Inference Time: 0.7333278467780665
# Per Image Inference Time: 0.09166598084725831
# Accuracy Check: 0.9166666666666666

# %%
misclassified = []
threshold = 0.6  # you can try 0.55, 0.6, 0.65

model.eval()

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)
        
        ai_probs = probs[:, 0]  # class 0 = ai
        
        # Correct threshold mapping
        preds = torch.where(
            ai_probs > threshold,
            torch.zeros_like(ai_probs).long(),   # Predict AI (0)
            torch.ones_like(ai_probs).long()     # Predict Real (1)
        )
        
        for i in range(len(labels)):
            if preds[i] != labels[i]:
                misclassified.append((labels[i].item(), preds[i].item()))

print("Total misclassified:", len(misclassified))
print("Accuracy:", 1 - len(misclassified)/len(val_dataset))
# Out:
# Total misclassified: 46
# Accuracy: 0.9233333333333333

# %% [markdown]
# RISK SCORE FORMULA

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 misclassified = []
# ----> 3 model.eval()
#       4 with torch.no_grad():
#       5     for images, labels in val_loader:
#
# NameError: name 'model' is not defined

# %%
pip install uvicorn
# Out:
# Collecting uvicorn
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: click>=7.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Installing collected packages: uvicorn
# Successfully installed uvicorn-0.40.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install "fastapi[standard]"
# Out:
# Collecting fastapi[standard]
#   Downloading fastapi-0.129.0-py3-none-any.whl.metadata (30 kB)
# Collecting starlette<1.0.0,>=0.40.0 (from fastapi[standard])
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from fastapi[standard]) (2.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from fastapi[standard]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from fastapi[standard]) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi[standard])
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cli-0.0.21-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from fastapi[standard]) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.5 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from fastapi[standard]) (3.1.6)
# Collecting python-multipart>=0.0.18 (from fastapi[standard])
#   Downloading python_multipart-0.0.22-py3-none-any.whl.metadata (1.8 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard])
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: uvicorn>=0.12.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (0.40.0)
# Collecting pydantic-settings>=2.0.0 (from fastapi[standard])
#   Downloading pydantic_settings-2.13.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[standard])
#   Downloading pydantic_extra_types-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: anyio in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (4.11.0)
# Requirement already satisfied: certifi in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (1.0.9)
# Requirement already satisfied: idna in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->fastapi[standard]) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1.0.0,>=0.23.0->fastapi[standard]) (1.3.1)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard])
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting typer>=0.15.1 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading typer-0.23.1-py3-none-any.whl.metadata (16 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rich_toolkit-0.19.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cloud_cli-0.12.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rignore-0.7.6-cp313-cp313-win_amd64.whl.metadata (4.3 kB)
# Collecting sentry-sdk>=2.20.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading sentry_sdk-2.52.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastar-0.8.0-cp313-cp313-win_amd64.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3.1.5->fastapi[standard]) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.0->fastapi[standard]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.0->fastapi[standard]) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings>=2.0.0->fastapi[standard]) (1.2.1)
# Requirement already satisfied: click>=8.1.7 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (8.3.1)
# Collecting rich>=13.7.1 (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rich-14.3.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from click>=8.1.7->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (0.4.6)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenova\appdata\roaming\python\python313\site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: urllib3>=1.26.11 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from sentry-sdk>=2.20.0->fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.6.2)
# Collecting shellingham>=1.3.0 (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading httptools-0.7.1-cp313-cp313-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenova\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (6.0.3)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading watchfiles-1.1.1-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Downloading fastapi-0.129.0-py3-none-any.whl (102 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Downloading fastapi_cli-0.0.21-py3-none-any.whl (12 kB)
# Downloading fastapi_cloud_cli-0.12.0-py3-none-any.whl (27 kB)
# Downloading fastar-0.8.0-cp313-cp313-win_amd64.whl (490 kB)
# Downloading pydantic_extra_types-2.11.0-py3-none-any.whl (74 kB)
# Downloading pydantic_settings-2.13.0-py3-none-any.whl (58 kB)
# Downloading python_multipart-0.0.22-py3-none-any.whl (24 kB)
# Downloading rich_toolkit-0.19.4-py3-none-any.whl (32 kB)
# Downloading rich-14.3.2-py3-none-any.whl (309 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading rignore-0.7.6-cp313-cp313-win_amd64.whl (726 kB)
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/726.2 kB ? eta -:--:--
#    ---------------------------------------- 726.2/726.2 kB 1.7 MB/s  0:00:00
# Downloading sentry_sdk-2.52.0-py2.py3-none-any.whl (435 kB)
# Downloading typer-0.23.1-py3-none-any.whl (56 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading httptools-0.7.1-cp313-cp313-win_amd64.whl (85 kB)
# Downloading watchfiles-1.1.1-cp313-cp313-win_amd64.whl (288 kB)
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Installing collected packages: websockets, shellingham, sentry-sdk, rignore, python-multipart, mdurl, httptools, fastar, dnspython, annotated-doc, watchfiles, starlette, markdown-it-py, email-validator, rich, pydantic-settings, pydantic-extra-types, fastapi, typer, rich-toolkit, fastapi-cloud-cli, fastapi-cli
#
#    ----------------------------------------  0/22 [websockets]
#    ----------------------------------------  0/22 [websockets]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    --- ------------------------------------  2/22 [sentry-sdk]
#    ------- --------------------------------  4/22 [python-multipart]
#    ------------ ---------------------------  7/22 [fastar]
#    -------------- -------------------------  8/22 [dnspython]
#    -------------- -------------------------  8/22 [dnspython]
#    -------------- -------------------------  8/22 [dnspython]
#    -------------- -------------------------  8/22 [dnspython]
#    -------------- -------------------------  8/22 [dnspython]
#    -------------- -------------------------  8/22 [dnspython]
#    ---------------- -----------------------  9/22 [annotated-doc]
#    -------------------- ------------------- 11/22 [starlette]
#    -------------------- ------------------- 11/22 [starlette]
#    --------------------- ------------------ 12/22 [markdown-it-py]
#    --------------------- ------------------ 12/22 [markdown-it-py]
#    ------------------------- -------------- 14/22 [rich]
#    ------------------------- -------------- 14/22 [rich]
#    ------------------------- -------------- 14/22 [rich]
#    ------------------------- -------------- 14/22 [rich]
#    ------------------------- -------------- 14/22 [rich]
#    ------------------------- -------------- 14/22 [rich]
#    --------------------------- ------------ 15/22 [pydantic-settings]
#    ----------------------------- ---------- 16/22 [pydantic-extra-types]
#    ------------------------------ --------- 17/22 [fastapi]
#    ------------------------------ --------- 17/22 [fastapi]
#    ------------------------------ --------- 17/22 [fastapi]
#    -------------------------------- ------- 18/22 [typer]
#    ---------------------------------- ----- 19/22 [rich-toolkit]
#    ------------------------------------ --- 20/22 [fastapi-cloud-cli]
#    ---------------------------------------- 22/22 [fastapi-cli]
#
# Successfully installed annotated-doc-0.0.4 dnspython-2.8.0 email-validator-2.3.0 fastapi-0.129.0 fastapi-cli-0.0.21 fastapi-cloud-cli-0.12.0 fastar-0.8.0 httptools-0.7.1 markdown-it-py-4.0.0 mdurl-0.1.2 pydantic-extra-types-2.11.0 pydantic-settings-2.13.0 python-multipart-0.0.22 rich-14.3.2 rich-toolkit-0.19.4 rignore-0.7.6 sentry-sdk-2.52.0 shellingham-1.5.4 starlette-0.52.1 typer-0.23.1 watchfiles-1.1.1 websockets-16.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
probs = torch.softmax(outputs, dim=1)
ai_probs = probs[:, 0]  # since 0 = ai
preds = (ai_probs > 0.6).long()

# %%
print(val_dataset.class_to_idx)
# Out:
# {'ai': 0, 'real': 1}
